# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13730 entries, 0 to 13729
# Columns: 167 entries, Unnamed: 0 to Q050
# dtypes: float64(28), int64(79), object(60)
# memory usage: 17.5+ MB

# %%
train.head(10)
# Out:
#    Unnamed: 0                              NU_INSCRICAO  NU_ANO  \
# 0           1  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad    2016
# 1           2  2c3acac4b33ec2b195d77e7c04a2d75727fad723    2016
# 2           3  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568    2016
# 3           4  3d6ec248fef899c414e77f82d5c6d2bffbeaf7fe    2016
# 4           5  bf896ac8d3ecadd6dba1dfbf50110afcbf5d3268    2016
# 5           6  a37c99ec251d4f6e8ddbeabadf1c87fdbfddc4d1    2016
# 6           7  63b4e128e9ffe8ab27f5d093db1976ef4f353e0a    2016
# 7           8  2eb189d4912f64b19d1967e8e84b6141aba18770    2016
# 8           9  5822cb43e0800429be2084b3f86a63aaa73fa66c    2016
# 9          10  94f7e277f87cd58e10a45da4ad5dd168651cf3ef    2016
#
#    CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# 0                  4314902            Porto Alegre                43
# 1                  2304707                  Granja                23
# ...

# %%
len(train)
# Out:
# 13730

# %%
sum(train['NU_NOTA_MT'].isna())
# Out:
# 3597

# %%
len(train['NU_NOTA_MT'].isna())
# Out:
# 13730

# %%
train['NO_MUNICIPIO_RESIDENCIA']
# Out:
# 0               Porto Alegre
# 1                     Granja
# 2                  Fortaleza
# 3             Rio de Janeiro
# 4                     Manaus
#                 ...
# 13725     Araçoiaba da Serra
# 13726     São Vicente Ferrer
# 13727         Tupanci do Sul
# 13728              Nilópolis
# 13729    Almirante Tamandaré
# Name: NO_MUNICIPIO_RESIDENCIA, Length: 13730, dtype: object

# %%
plt.figure( figsize=(18,8))
sns.heatmap(train.isna(), yticklabels=False, cbar=False, cmap='viridis' )

# %%
train['NU_NOTA_MT'].describe().plot()

# %%
train['NU_NOTA_MT'].describe()
# Out:
# count    10133.000000
# mean       482.497928
# std         99.826323
# min          0.000000
# 25%        408.900000
# 50%        461.200000
# 75%        537.600000
# max        952.000000
# Name: NU_NOTA_MT, dtype: float64

# %%
questoes = np.arange(2,51)
questoes =  pd.Series(questoes)
questoes.apply(lambda x:  'Q0' + str(x))
# Out:
# 0      Q02
# 1      Q03
# 2      Q04
# 3      Q05
# 4      Q06
# 5      Q07
# 6      Q08
# 7      Q09
# 8     Q010
# 9     Q011
# 10    Q012
# 11    Q013
# 12    Q014
# 13    Q015
# 14    Q016
# 15    Q017
# 16    Q018
# 17    Q019
# 18    Q020
# 19    Q021
# 20    Q022
# 21    Q023
# 22    Q024
# 23    Q025
# 24    Q026
# 25    Q027
# 26    Q028
# 27    Q029
# 28    Q030
# 29    Q031
# 30    Q032
# 31    Q033
# 32    Q034
# 33    Q035
# 34    Q036
# 35    Q037
# 36    Q038
# 37    Q039
# 38    Q040
# 39    Q041
# 40    Q042
# 41    Q043
# 42    Q044
# 43    Q045
# 44    Q046
# 45    Q047
# 46    Q048
# 47    Q049
# 48    Q050
# dtype: object

# %%
plt.figure(figsize=(18,8))
sns.heatmap(train.corr())

# %%
train.groupby('SG_UF_RESIDENCIA')['NU_NOTA_MT'].mean().sort_values(ascending= False)[:10]
# Out:
# SG_UF_RESIDENCIA
# DF    510.527160
# RJ    510.125693
# MG    506.948713
# SP    503.945071
# RS    494.639418
# SC    494.447368
# RN    491.767914
# PR    490.541333
# RR    486.386364
# ES    480.883412
# Name: NU_NOTA_MT, dtype: float64

# %%
plt.figure(figsize=(18,6))
train.groupby('SG_UF_RESIDENCIA')['NU_NOTA_MT'].mean().sort_values(ascending=False)[:10].plot()

# %%
plt.figure(figsize=(18,6))
train.groupby('SG_UF_RESIDENCIA')['NU_NOTA_MT'].mean().sort_values(ascending=False)[10:].plot()

# %%
train.groupby('NO_MUNICIPIO_RESIDENCIA')['NU_NOTA_MT'].mean().sort_values(ascending=False)[:15]
# Out:
# NO_MUNICIPIO_RESIDENCIA
# Promissão               812.10
# Santa Vitória           805.10
# São Pedro dos Ferros    790.70
# Gália                   788.40
# Santa Isabel            776.00
# São Pedro do Suaçuí     771.10
# Leme do Prado           769.90
# Pinhão                  759.40
# Três de Maio            758.30
# Duartina                757.40
# Marechal Floriano       757.20
# Agudo                   745.60
# Primavera do Leste      738.65
# Igarapava               736.70
# Juruti                  731.10
# Name: NU_NOTA_MT, dtype: float64

# %%
train['NU_ANO'].unique()
# Out:
# array([2016], dtype=int64)

# %%
train['TP_ESTADO_CIVIL'].value_counts()
# Out:
# 0.0    11860
# 1.0     1169
# 2.0      156
# 3.0       17
# Name: TP_ESTADO_CIVIL, dtype: int64
